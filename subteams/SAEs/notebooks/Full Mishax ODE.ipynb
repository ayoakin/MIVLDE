# %%
import enum
import strenum
import sys
from typing import Callable, TypeAlias
import torch
import torch.nn as nn
import torch.nn.functional as F
from mishax import ast_patcher
from mishax import safe_greenlet
import numpy as np
import matplotlib.pyplot as plt
import odeformer

import scipy.integrate
import sympy as sp
import pickle
from pathlib import Path
import matplotlib.pyplot as plt

# %%
from odeformer.model import SymbolicTransformerRegressor
from transformer import MultiHeadAttention, TransformerFFN

from odeformer.metrics import r2_score

# %%
class Site(strenum.StrEnum):
    """Instrumentation sites within an ODEFormer forward pass."""
    # Attention sites
    QUERY = enum.auto()
    KEY = enum.auto()
    VALUE = enum.auto()
    ATTN_SCORES = enum.auto()
    ATTN_PROBS = enum.auto()
    ATTN_OUTPUT = enum.auto()
    POST_ATTN_RESIDUAL = enum.auto()

    # Layer norm sites
    PRE_ATTN_LAYERNORM = enum.auto()
    PRE_MLP_LAYERNORM = enum.auto()

    # MLP sites
    MLP_INPUT = enum.auto()
    MLP_HIDDEN = enum.auto()
    MLP_OUTPUT = enum.auto()
    POST_MLP_RESIDUAL = enum.auto()

    # Cross attention (decoder only)
    CROSS_ATTN_SCORES = enum.auto()
    CROSS_ATTN_PROBS = enum.auto()
    CROSS_ATTN_OUTPUT = enum.auto()

class ModulePathMapper:
    """Maps modules to their full paths including component names."""
    def __init__(self, model):
        self.path_map = {}
        self.model = model

        # Get paths from transformer components
        if hasattr(model, 'model'):
            model = model.model
            if hasattr(model, 'encoder'):
                for name, module in model.encoder.named_modules():
                    self.path_map[id(module)] = f"encoder.{name}"

            if hasattr(model, 'decoder'):
                for name, module in model.decoder.named_modules():
                    self.path_map[id(module)] = f"decoder.{name}"

    def get_layer_path(self, module: nn.Module, accessing_component: str = None) -> str:
        """Gets the full hierarchical path including the accessed component."""
        base_path = self.path_map.get(id(module))
        if base_path is None:
            return None

        # If accessing a specific component, append it
        if accessing_component:
            return f"{base_path}.{accessing_component}"

        return base_path

    def get_accessing_component(self, module: nn.Module, attr_name: str) -> str:
        """Gets the name of the component being accessed."""
        if hasattr(module, attr_name):
            component = getattr(module, attr_name)
            if isinstance(component, nn.Linear):
                return attr_name
        return None

_path_mapper = None

def _tag(module: nn.Module, site: Site, value: torch.Tensor, accessing: str = None) -> torch.Tensor:
    """Tags a value at a particular site for instrumentation."""
    try:
        parent = safe_greenlet.getparent()
        if parent is None:
            return value

        # Get full path including component
        path = None
        if _path_mapper is not None:
            path = _path_mapper.get_layer_path(module, accessing)

        ret = parent.switch((site, value, path))
        return ret if ret is not None else value
    except Exception as e:
        print(f"Error in tag at {site}: {e}")
        return value


def collect_activations_during_fit(model, times, trajectories):
    """Collects activations during model.fit()."""
    global _path_mapper
    _path_mapper = ModulePathMapper(model)
    return collect_activations(lambda: model.fit(times, trajectories))

def view_layer_paths(activations):
    """Displays activations organized by full layer paths."""
    print("\nActivations by Layer Path:")
    print("-------------------------")

    # Group by model section and type
    sections = {
        'encoder': {
            'attention': [],
            'ffn': []
        },
        'decoder': {
            'attention': [],
            'ffn': [],
            'encoder_attn': []
        }
    }

    # Collect unique paths and sort them
    for site_data in activations.values():
        for path in site_data.keys():
            if path is None:
                continue

            # Determine section and type
            if 'encoder.' in path:
                if any(x in path for x in ['q_lin', 'k_lin', 'v_lin', 'out_lin']):
                    sections['encoder']['attention'].append(path)
                elif any(x in path for x in ['lin1', 'lin2']):
                    sections['encoder']['ffn'].append(path)
            elif 'decoder.' in path:
                if 'encoder_attn' in path:
                    sections['decoder']['encoder_attn'].append(path)
                elif any(x in path for x in ['q_lin', 'k_lin', 'v_lin', 'out_lin']):
                    sections['decoder']['attention'].append(path)
                elif any(x in path for x in ['lin1', 'lin2']):
                    sections['decoder']['ffn'].append(path)

    # Print organized by section
    for section in ['encoder', 'decoder']:
        print(f"\n{section.upper()}:")
        for component_type, paths in sections[section].items():
            if paths:
                print(f"\n  {component_type}:")
                for path in sorted(set(paths)):
                    # Find this path in activations
                    for site, site_data in activations.items():
                        if path in site_data:
                            print(f"    {path}:")
                            for shape, tensor in site_data[path].items():
                                print(f"      Shape {shape}: {tensor.shape[0]} activations")

def install():
    """Installs the patchers to instrument the model."""
    print("\nInstalling patches...")

    PREFIX = f"""from {__name__} import Site, _tag as tag"""


    patcher = ast_patcher.ModuleASTPatcher(
        odeformer.model.transformer,
        ast_patcher.PatchSettings(
            prefix=PREFIX,
            allow_num_matches_upto={}  # If need to allow multiple matches
        ),
        MultiHeadAttention=[
            # Self-attention computation chain
            """        scores = torch.matmul(q, k.transpose(2, 3))  # (bs, n_heads, qlen, klen)""",
            """        scores = tag(self, Site.ATTN_SCORES, torch.matmul(q, k.transpose(2, 3)), accessing='scores')  # (bs, n_heads, qlen, klen)""",

            """        weights = F.softmax(scores.float(), dim=-1).type_as(scores)""",
            """        weights = tag(self, Site.ATTN_PROBS, F.softmax(scores.float(), dim=-1).type_as(scores), accessing='weights')""",

            """        context = torch.matmul(weights, v)""",
            """        context = tag(self, Site.ATTN_OUTPUT, torch.matmul(weights, v), accessing='context')"""
        ],
        TransformerModel=[
            # LayerNorm and attention
            """            attn = self.attentions[i](tensor, attn_mask, use_cache=use_cache)""",
            """            attn = tag(self, Site.ATTN_OUTPUT, self.attentions[i](tensor, attn_mask, use_cache=use_cache), accessing='attention_layer')"""
        ],
        TransformerFFN=[
            # Inside FFN
            """        x = self.lin1(input)""",
            """        x = self.lin1(tag(self, Site.MLP_INPUT, input, accessing='lin1'))""",

            """        x = self.lin2(x)""",
            """        x = tag(self, Site.MLP_OUTPUT, self.lin2(x), accessing='lin2')""",
        ]
    )

    try:
        patcher.install()
        print("\nPatches installed successfully")
    except Exception as e:
        print(f"\nError installing patches: {e}")
        import traceback
        traceback.print_exc()

    return patcher



def collect_activations(model_fn):
    """Collects activations during a model function execution."""
    print("\nStarting activation collection")
    activations = {}

    patcher = install()
    with patcher():
        def run_in_greenlet():
            try:
                print("Starting model execution in greenlet...")
                result = model_fn()
                print("Model execution completed")
                return result
            except Exception as e:
                print(f"Error in greenlet execution: {e}")
                import traceback
                traceback.print_exc()
                raise

        glet = safe_greenlet.SafeGreenlet(run_in_greenlet)
        print(f"Created SafeGreenlet: {glet}")

        with glet:
            try:
                print("Starting greenlet...")
                result = glet.switch()
                print("Initial switch complete")

                while glet:
                    site, value, name = result

                    # Initialize storage for this site if needed
                    if site not in activations:
                        activations[site] = {}

                    # Store by name within each site
                    if name not in activations[site]:
                        activations[site][name] = []

                    if torch.is_tensor(value):
                        activations[site][name].append(value.detach().cpu())

                    try:
                        result = glet.switch(value)
                    except StopIteration:
                        break

            except Exception as e:
                print(f"Error in activation collection: {e}")
                import traceback
                traceback.print_exc()
                raise

    print(f"Collection complete. Found sites: {list(activations.keys())}")

    if activations:
        print("\nProcessing activations...")

        # Process activations into a more structured format
        processed_activations = {}
        for site, name_data in activations.items():
            processed_activations[site] = {}

            for name, tensor_list in name_data.items():
                # Group tensors by shape
                shape_groups = {}
                for tensor in tensor_list:
                    shape = tuple(tensor.shape)
                    if shape not in shape_groups:
                        shape_groups[shape] = []
                    shape_groups[shape].append(tensor)

                # Store processed data
                processed_activations[site][name] = {
                    shape: torch.stack(tensors)
                    for shape, tensors in shape_groups.items()
                }

            # Print information
            print(f"\n{site}:")
            for name in processed_activations[site]:
                print(f"  Name: {name}")
                for shape, tensor in processed_activations[site][name].items():
                    print(f"    Shape {shape}: {tensor.shape[0]} tensors")

    return processed_activations, result

# %%
# First install patches
install()
# Out:
# Installing patches...
#
# Patches installed successfully

# %%
model = SymbolicTransformerRegressor(
    from_pretrained=True)

model_args = {'beam_size':20,
        'beam_temperature':0.1}
model.set_model_args(model_args)
# Out:
# Found pretrained model at odeformer.pt
# Loaded pretrained model

# %%
with open('lotka_volterra.pkl', 'rb') as f:
    solutions = pickle.load(f)

# %%
# Then collect activations
np.infty=np.inf
times = np.linspace(0, 10, 50)
x = np.cos(times+.1)
y = np.sin(times+.1)
trajectory = np.stack([x, y], axis=1)

# %%
trajectory=solutions[0]['solution']
times = solutions[0]['time_points']

# %%
#model.fit(times, trajectory)
fit_activations, outputs = collect_activations_during_fit(model, times, trajectory)
# Out:
# Starting activation collection
#
# Installing patches...
#
# Patches installed successfully
# Created SafeGreenlet: <SafeGreenlet object at 0x7fb279a36380 (otid=0x(nil)) pending>
# Starting greenlet...
# Starting model execution in greenlet...
# Initial switch complete
# Model execution completed
# Collection complete. Found sites: [<Site.ATTN_SCORES: 'ATTN_SCORES'>, <Site.ATTN_PROBS: 'ATTN_PROBS'>, <Site.ATTN_OUTPUT: 'ATTN_OUTPUT'>, <Site.MLP_INPUT: 'MLP_INPUT'>, <Site.MLP_OUTPUT: 'MLP_OUTPUT'>]
#
# Processing activations...
#
# ATTN_SCORES:
#   Name: encoder.attentions.0.scores
#     Shape (1, 16, 100, 100): 1 tensors
#   Name: encoder.attentions.1.scores
#     Shape (1, 16, 100, 100): 1 tensors
#   Name: encoder.attentions.2.scores
#     Shape (1, 16, 100, 100): 1 tensors
#   Name: encoder.attentions.3.scores
#     Shape (1, 16, 100, 100): 1 tensors
#   Name: decoder.attentions.0.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.0.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.1.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.1.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.2.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.2.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.3.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.3.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.4.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.4.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.5.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.5.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.6.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.6.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.7.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.7.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.8.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.8.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.9.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.9.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.10.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.10.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.11.scores
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.11.scores
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#
# ATTN_PROBS:
#   Name: encoder.attentions.0.weights
#     Shape (1, 16, 100, 100): 1 tensors
#   Name: encoder.attentions.1.weights
#     Shape (1, 16, 100, 100): 1 tensors
#   Name: encoder.attentions.2.weights
#     Shape (1, 16, 100, 100): 1 tensors
#   Name: encoder.attentions.3.weights
#     Shape (1, 16, 100, 100): 1 tensors
#   Name: decoder.attentions.0.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.0.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.1.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.1.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.2.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.2.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.3.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.3.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.4.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.4.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.5.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.5.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.6.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.6.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.7.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.7.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.8.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.8.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.9.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.9.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.10.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.10.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#   Name: decoder.attentions.11.weights
#     Shape (1, 16, 1, 1): 1 tensors
#     Shape (1, 16, 1, 2): 1 tensors
#     Shape (1, 16, 1, 3): 1 tensors
#     Shape (1, 16, 1, 4): 1 tensors
#     Shape (1, 16, 1, 5): 1 tensors
#     Shape (1, 16, 1, 6): 1 tensors
#     Shape (1, 16, 1, 7): 1 tensors
#     Shape (1, 16, 1, 8): 1 tensors
#     Shape (1, 16, 1, 9): 1 tensors
#     Shape (1, 16, 1, 10): 1 tensors
#     Shape (1, 16, 1, 11): 1 tensors
#     Shape (1, 16, 1, 12): 1 tensors
#     Shape (1, 16, 1, 13): 1 tensors
#     Shape (1, 16, 1, 14): 1 tensors
#     Shape (1, 16, 1, 15): 1 tensors
#     Shape (1, 16, 1, 16): 1 tensors
#     Shape (1, 16, 1, 17): 1 tensors
#     Shape (1, 16, 1, 18): 1 tensors
#     Shape (1, 16, 1, 19): 1 tensors
#     Shape (1, 16, 1, 20): 1 tensors
#     Shape (1, 16, 1, 21): 1 tensors
#     Shape (1, 16, 1, 22): 1 tensors
#     Shape (1, 16, 1, 23): 1 tensors
#     Shape (1, 16, 1, 24): 1 tensors
#     Shape (1, 16, 1, 25): 1 tensors
#     Shape (1, 16, 1, 26): 1 tensors
#     Shape (1, 16, 1, 27): 1 tensors
#     Shape (1, 16, 1, 28): 1 tensors
#     Shape (20, 16, 1, 1): 1 tensors
#     Shape (20, 16, 1, 2): 1 tensors
#     Shape (20, 16, 1, 3): 1 tensors
#     Shape (20, 16, 1, 4): 1 tensors
#     Shape (20, 16, 1, 5): 1 tensors
#     Shape (20, 16, 1, 6): 1 tensors
#     Shape (20, 16, 1, 7): 1 tensors
#     Shape (20, 16, 1, 8): 1 tensors
#     Shape (20, 16, 1, 9): 1 tensors
#     Shape (20, 16, 1, 10): 1 tensors
#     Shape (20, 16, 1, 11): 1 tensors
#     Shape (20, 16, 1, 12): 1 tensors
#     Shape (20, 16, 1, 13): 1 tensors
#     Shape (20, 16, 1, 14): 1 tensors
#     Shape (20, 16, 1, 15): 1 tensors
#     Shape (20, 16, 1, 16): 1 tensors
#     Shape (20, 16, 1, 17): 1 tensors
#     Shape (20, 16, 1, 18): 1 tensors
#     Shape (20, 16, 1, 19): 1 tensors
#     Shape (20, 16, 1, 20): 1 tensors
#     Shape (20, 16, 1, 21): 1 tensors
#     Shape (20, 16, 1, 22): 1 tensors
#     Shape (20, 16, 1, 23): 1 tensors
#     Shape (20, 16, 1, 24): 1 tensors
#     Shape (20, 16, 1, 25): 1 tensors
#     Shape (20, 16, 1, 26): 1 tensors
#     Shape (20, 16, 1, 27): 1 tensors
#     Shape (20, 16, 1, 28): 1 tensors
#   Name: decoder.encoder_attn.11.weights
#     Shape (1, 16, 1, 100): 28 tensors
#     Shape (20, 16, 1, 100): 28 tensors
#
# ATTN_OUTPUT:
#   Name: encoder.attentions.0.context
#     Shape (1, 16, 100, 16): 1 tensors
#   Name: encoder..attention_layer
#     Shape (1, 100, 256): 4 tensors
#   Name: encoder.attentions.1.context
#     Shape (1, 16, 100, 16): 1 tensors
#   Name: encoder.attentions.2.context
#     Shape (1, 16, 100, 16): 1 tensors
#   Name: encoder.attentions.3.context
#     Shape (1, 16, 100, 16): 1 tensors
#   Name: decoder.attentions.0.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder..attention_layer
#     Shape (1, 1, 512): 336 tensors
#     Shape (20, 1, 512): 336 tensors
#   Name: decoder.encoder_attn.0.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.1.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.1.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.2.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.2.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.3.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.3.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.4.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.4.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.5.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.5.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.6.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.6.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.7.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.7.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.8.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.8.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.9.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.9.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.10.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.10.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.attentions.11.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#   Name: decoder.encoder_attn.11.context
#     Shape (1, 16, 1, 32): 28 tensors
#     Shape (20, 16, 1, 32): 28 tensors
#
# MLP_INPUT:
#   Name: encoder.ffns.0.lin1
#     Shape (1, 100, 256): 1 tensors
#   Name: encoder.ffns.1.lin1
#     Shape (1, 100, 256): 1 tensors
#   Name: encoder.ffns.2.lin1
#     Shape (1, 100, 256): 1 tensors
#   Name: encoder.ffns.3.lin1
#     Shape (1, 100, 256): 1 tensors
#   Name: decoder.ffns.0.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.1.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.2.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.3.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.4.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.5.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.6.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.7.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.8.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.9.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.10.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.11.lin1
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#
# MLP_OUTPUT:
#   Name: encoder.ffns.0.lin2
#     Shape (1, 100, 256): 1 tensors
#   Name: encoder.ffns.1.lin2
#     Shape (1, 100, 256): 1 tensors
#   Name: encoder.ffns.2.lin2
#     Shape (1, 100, 256): 1 tensors
#   Name: encoder.ffns.3.lin2
#     Shape (1, 100, 256): 1 tensors
#   Name: decoder.ffns.0.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.1.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.2.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.3.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.4.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.5.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.6.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.7.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.8.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.9.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.10.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors
#   Name: decoder.ffns.11.lin2
#     Shape (1, 1, 512): 28 tensors
#     Shape (20, 1, 512): 28 tensors

# %%
outputs[0][0]
# Out:
# 0.4878 * x_0 + -0.1872 * x_0 * x_1 | -0.3038 * x_1 + 0.2110 * x_0 * x_1

# %%
view_layer_paths(fit_activations)
# Out:
# Activations by Layer Path:
# -------------------------
#
# ENCODER:
#
#   ffn:
#     encoder.ffns.0.lin1:
#       Shape (1, 100, 256): 1 activations
#     encoder.ffns.0.lin2:
#       Shape (1, 100, 256): 1 activations
#     encoder.ffns.1.lin1:
#       Shape (1, 100, 256): 1 activations
#     encoder.ffns.1.lin2:
#       Shape (1, 100, 256): 1 activations
#     encoder.ffns.2.lin1:
#       Shape (1, 100, 256): 1 activations
#     encoder.ffns.2.lin2:
#       Shape (1, 100, 256): 1 activations
#     encoder.ffns.3.lin1:
#       Shape (1, 100, 256): 1 activations
#     encoder.ffns.3.lin2:
#       Shape (1, 100, 256): 1 activations
#
# DECODER:
#
#   ffn:
#     decoder.ffns.0.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.0.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.1.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.1.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.10.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.10.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.11.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.11.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.2.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.2.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.3.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.3.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.4.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.4.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.5.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.5.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.6.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.6.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.7.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.7.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.8.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.8.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.9.lin1:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#     decoder.ffns.9.lin2:
#       Shape (1, 1, 512): 28 activations
#       Shape (20, 1, 512): 28 activations
#
#   encoder_attn:
#     decoder.encoder_attn.0.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.0.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.0.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.1.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.1.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.1.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.10.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.10.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.10.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.11.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.11.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.11.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.2.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.2.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.2.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.3.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.3.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.3.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.4.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.4.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.4.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.5.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.5.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.5.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.6.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.6.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.6.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.7.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.7.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.7.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.8.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.8.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.8.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.9.context:
#       Shape (1, 16, 1, 32): 28 activations
#       Shape (20, 16, 1, 32): 28 activations
#     decoder.encoder_attn.9.scores:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations
#     decoder.encoder_attn.9.weights:
#       Shape (1, 16, 1, 100): 28 activations
#       Shape (20, 16, 1, 100): 28 activations

# %%
for name, layer in model.model.named_modules():
    print(name, layer)
# Out:
#  ModelWrapper(
#   (embedder): LinearPointEmbedder(
#     (embeddings): Embedding(10220, 64, padding_idx=9)
#     (hidden_layers): ModuleList(
#       (0): Linear(in_features=1344, out_features=1344, bias=True)
#     )
#     (fc): Linear(in_features=1344, out_features=256, bias=True)
#   )
#   (encoder): TransformerModel(
#     (layer_norm_emb): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#     (attentions): ModuleList(
#       (0-3): 4 x MultiHeadAttention(
#         (q_lin): Linear(in_features=256, out_features=256, bias=True)
#         (k_lin): Linear(in_features=256, out_features=256, bias=True)
#         (v_lin): Linear(in_features=256, out_features=256, bias=True)
#         (out_lin): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (layer_norm1): ModuleList(
#       (0-3): 4 x LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#     )
#     (ffns): ModuleList(
#       (0-3): 4 x TransformerFFN(
#         (midlin): ModuleList()
#         (lin1): Linear(in_features=256, out_features=1024, bias=True)
#         (lin2): Linear(in_features=1024, out_features=256, bias=True)
#       )
#     )
#     (layer_norm2): ModuleList(
#       (0-3): 4 x LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#     )
#   )
#   (decoder): TransformerModel(
#     (position_embeddings): Embedding(4096, 512)
#     (embeddings): Embedding(10293, 512, padding_idx=82)
#     (layer_norm_emb): LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#     (attentions): ModuleList(
#       (0-11): 12 x MultiHeadAttention(
#         (q_lin): Linear(in_features=512, out_features=512, bias=True)
#         (k_lin): Linear(in_features=512, out_features=512, bias=True)
#         (v_lin): Linear(in_features=512, out_features=512, bias=True)
#         (out_lin): Linear(in_features=512, out_features=512, bias=True)
#       )
#     )
#     (layer_norm1): ModuleList(
#       (0-11): 12 x LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#     )
#     (ffns): ModuleList(
#       (0-11): 12 x TransformerFFN(
#         (midlin): ModuleList()
#         (lin1): Linear(in_features=512, out_features=2048, bias=True)
#         (lin2): Linear(in_features=2048, out_features=512, bias=True)
#       )
#     )
#     (layer_norm2): ModuleList(
#       (0-11): 12 x LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#     )
#     (layer_norm15): ModuleList(
#       (0-11): 12 x LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#     )
#     (encoder_attn): ModuleList(
#       (0-11): 12 x MultiHeadAttention(
#         (q_lin): Linear(in_features=512, out_features=512, bias=True)
#         (k_lin): Linear(in_features=256, out_features=512, bias=True)
#         (v_lin): Linear(in_features=256, out_features=512, bias=True)
#         (out_lin): Linear(in_features=512, out_features=512, bias=True)
#       )
#     )
#     (proj): Linear(in_features=512, out_features=10293, bias=True)
#   )
# )
# embedder LinearPointEmbedder(
#   (embeddings): Embedding(10220, 64, padding_idx=9)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=1344, out_features=1344, bias=True)
#   )
#   (fc): Linear(in_features=1344, out_features=256, bias=True)
# )
# embedder.embeddings Embedding(10220, 64, padding_idx=9)
# embedder.hidden_layers ModuleList(
#   (0): Linear(in_features=1344, out_features=1344, bias=True)
# )
# embedder.hidden_layers.0 Linear(in_features=1344, out_features=1344, bias=True)
# embedder.fc Linear(in_features=1344, out_features=256, bias=True)
# encoder TransformerModel(
#   (layer_norm_emb): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#   (attentions): ModuleList(
#     (0-3): 4 x MultiHeadAttention(
#       (q_lin): Linear(in_features=256, out_features=256, bias=True)
#       (k_lin): Linear(in_features=256, out_features=256, bias=True)
#       (v_lin): Linear(in_features=256, out_features=256, bias=True)
#       (out_lin): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (layer_norm1): ModuleList(
#     (0-3): 4 x LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#   )
#   (ffns): ModuleList(
#     (0-3): 4 x TransformerFFN(
#       (midlin): ModuleList()
#       (lin1): Linear(in_features=256, out_features=1024, bias=True)
#       (lin2): Linear(in_features=1024, out_features=256, bias=True)
#     )
#   )
#   (layer_norm2): ModuleList(
#     (0-3): 4 x LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#   )
# )
# encoder.layer_norm_emb LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# encoder.attentions ModuleList(
#   (0-3): 4 x MultiHeadAttention(
#     (q_lin): Linear(in_features=256, out_features=256, bias=True)
#     (k_lin): Linear(in_features=256, out_features=256, bias=True)
#     (v_lin): Linear(in_features=256, out_features=256, bias=True)
#     (out_lin): Linear(in_features=256, out_features=256, bias=True)
#   )
# )
# encoder.attentions.0 MultiHeadAttention(
#   (q_lin): Linear(in_features=256, out_features=256, bias=True)
#   (k_lin): Linear(in_features=256, out_features=256, bias=True)
#   (v_lin): Linear(in_features=256, out_features=256, bias=True)
#   (out_lin): Linear(in_features=256, out_features=256, bias=True)
# )
# encoder.attentions.0.q_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.0.k_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.0.v_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.0.out_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.1 MultiHeadAttention(
#   (q_lin): Linear(in_features=256, out_features=256, bias=True)
#   (k_lin): Linear(in_features=256, out_features=256, bias=True)
#   (v_lin): Linear(in_features=256, out_features=256, bias=True)
#   (out_lin): Linear(in_features=256, out_features=256, bias=True)
# )
# encoder.attentions.1.q_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.1.k_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.1.v_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.1.out_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.2 MultiHeadAttention(
#   (q_lin): Linear(in_features=256, out_features=256, bias=True)
#   (k_lin): Linear(in_features=256, out_features=256, bias=True)
#   (v_lin): Linear(in_features=256, out_features=256, bias=True)
#   (out_lin): Linear(in_features=256, out_features=256, bias=True)
# )
# encoder.attentions.2.q_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.2.k_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.2.v_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.2.out_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.3 MultiHeadAttention(
#   (q_lin): Linear(in_features=256, out_features=256, bias=True)
#   (k_lin): Linear(in_features=256, out_features=256, bias=True)
#   (v_lin): Linear(in_features=256, out_features=256, bias=True)
#   (out_lin): Linear(in_features=256, out_features=256, bias=True)
# )
# encoder.attentions.3.q_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.3.k_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.3.v_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.attentions.3.out_lin Linear(in_features=256, out_features=256, bias=True)
# encoder.layer_norm1 ModuleList(
#   (0-3): 4 x LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# )
# encoder.layer_norm1.0 LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# encoder.layer_norm1.1 LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# encoder.layer_norm1.2 LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# encoder.layer_norm1.3 LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# encoder.ffns ModuleList(
#   (0-3): 4 x TransformerFFN(
#     (midlin): ModuleList()
#     (lin1): Linear(in_features=256, out_features=1024, bias=True)
#     (lin2): Linear(in_features=1024, out_features=256, bias=True)
#   )
# )
# encoder.ffns.0 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=256, out_features=1024, bias=True)
#   (lin2): Linear(in_features=1024, out_features=256, bias=True)
# )
# encoder.ffns.0.midlin ModuleList()
# encoder.ffns.0.lin1 Linear(in_features=256, out_features=1024, bias=True)
# encoder.ffns.0.lin2 Linear(in_features=1024, out_features=256, bias=True)
# encoder.ffns.1 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=256, out_features=1024, bias=True)
#   (lin2): Linear(in_features=1024, out_features=256, bias=True)
# )
# encoder.ffns.1.midlin ModuleList()
# encoder.ffns.1.lin1 Linear(in_features=256, out_features=1024, bias=True)
# encoder.ffns.1.lin2 Linear(in_features=1024, out_features=256, bias=True)
# encoder.ffns.2 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=256, out_features=1024, bias=True)
#   (lin2): Linear(in_features=1024, out_features=256, bias=True)
# )
# encoder.ffns.2.midlin ModuleList()
# encoder.ffns.2.lin1 Linear(in_features=256, out_features=1024, bias=True)
# encoder.ffns.2.lin2 Linear(in_features=1024, out_features=256, bias=True)
# encoder.ffns.3 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=256, out_features=1024, bias=True)
#   (lin2): Linear(in_features=1024, out_features=256, bias=True)
# )
# encoder.ffns.3.midlin ModuleList()
# encoder.ffns.3.lin1 Linear(in_features=256, out_features=1024, bias=True)
# encoder.ffns.3.lin2 Linear(in_features=1024, out_features=256, bias=True)
# encoder.layer_norm2 ModuleList(
#   (0-3): 4 x LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# )
# encoder.layer_norm2.0 LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# encoder.layer_norm2.1 LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# encoder.layer_norm2.2 LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# encoder.layer_norm2.3 LayerNorm((256,), eps=1e-12, elementwise_affine=True)
# decoder TransformerModel(
#   (position_embeddings): Embedding(4096, 512)
#   (embeddings): Embedding(10293, 512, padding_idx=82)
#   (layer_norm_emb): LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#   (attentions): ModuleList(
#     (0-11): 12 x MultiHeadAttention(
#       (q_lin): Linear(in_features=512, out_features=512, bias=True)
#       (k_lin): Linear(in_features=512, out_features=512, bias=True)
#       (v_lin): Linear(in_features=512, out_features=512, bias=True)
#       (out_lin): Linear(in_features=512, out_features=512, bias=True)
#     )
#   )
#   (layer_norm1): ModuleList(
#     (0-11): 12 x LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#   )
#   (ffns): ModuleList(
#     (0-11): 12 x TransformerFFN(
#       (midlin): ModuleList()
#       (lin1): Linear(in_features=512, out_features=2048, bias=True)
#       (lin2): Linear(in_features=2048, out_features=512, bias=True)
#     )
#   )
#   (layer_norm2): ModuleList(
#     (0-11): 12 x LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#   )
#   (layer_norm15): ModuleList(
#     (0-11): 12 x LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#   )
#   (encoder_attn): ModuleList(
#     (0-11): 12 x MultiHeadAttention(
#       (q_lin): Linear(in_features=512, out_features=512, bias=True)
#       (k_lin): Linear(in_features=256, out_features=512, bias=True)
#       (v_lin): Linear(in_features=256, out_features=512, bias=True)
#       (out_lin): Linear(in_features=512, out_features=512, bias=True)
#     )
#   )
#   (proj): Linear(in_features=512, out_features=10293, bias=True)
# )
# decoder.position_embeddings Embedding(4096, 512)
# decoder.embeddings Embedding(10293, 512, padding_idx=82)
# decoder.layer_norm_emb LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.attentions ModuleList(
#   (0-11): 12 x MultiHeadAttention(
#     (q_lin): Linear(in_features=512, out_features=512, bias=True)
#     (k_lin): Linear(in_features=512, out_features=512, bias=True)
#     (v_lin): Linear(in_features=512, out_features=512, bias=True)
#     (out_lin): Linear(in_features=512, out_features=512, bias=True)
#   )
# )
# decoder.attentions.0 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.0.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.0.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.0.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.0.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.1 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.1.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.1.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.1.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.1.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.2 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.2.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.2.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.2.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.2.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.3 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.3.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.3.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.3.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.3.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.4 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.4.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.4.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.4.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.4.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.5 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.5.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.5.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.5.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.5.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.6 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.6.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.6.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.6.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.6.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.7 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.7.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.7.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.7.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.7.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.8 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.8.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.8.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.8.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.8.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.9 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.9.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.9.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.9.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.9.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.10 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.10.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.10.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.10.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.10.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.11 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=512, out_features=512, bias=True)
#   (v_lin): Linear(in_features=512, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.attentions.11.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.11.k_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.11.v_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.attentions.11.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.layer_norm1 ModuleList(
#   (0-11): 12 x LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# )
# decoder.layer_norm1.0 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.1 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.2 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.3 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.4 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.5 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.6 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.7 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.8 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.9 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.10 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm1.11 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.ffns ModuleList(
#   (0-11): 12 x TransformerFFN(
#     (midlin): ModuleList()
#     (lin1): Linear(in_features=512, out_features=2048, bias=True)
#     (lin2): Linear(in_features=2048, out_features=512, bias=True)
#   )
# )
# decoder.ffns.0 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.0.midlin ModuleList()
# decoder.ffns.0.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.0.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.1 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.1.midlin ModuleList()
# decoder.ffns.1.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.1.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.2 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.2.midlin ModuleList()
# decoder.ffns.2.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.2.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.3 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.3.midlin ModuleList()
# decoder.ffns.3.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.3.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.4 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.4.midlin ModuleList()
# decoder.ffns.4.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.4.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.5 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.5.midlin ModuleList()
# decoder.ffns.5.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.5.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.6 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.6.midlin ModuleList()
# decoder.ffns.6.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.6.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.7 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.7.midlin ModuleList()
# decoder.ffns.7.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.7.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.8 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.8.midlin ModuleList()
# decoder.ffns.8.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.8.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.9 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.9.midlin ModuleList()
# decoder.ffns.9.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.9.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.10 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.10.midlin ModuleList()
# decoder.ffns.10.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.10.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.ffns.11 TransformerFFN(
#   (midlin): ModuleList()
#   (lin1): Linear(in_features=512, out_features=2048, bias=True)
#   (lin2): Linear(in_features=2048, out_features=512, bias=True)
# )
# decoder.ffns.11.midlin ModuleList()
# decoder.ffns.11.lin1 Linear(in_features=512, out_features=2048, bias=True)
# decoder.ffns.11.lin2 Linear(in_features=2048, out_features=512, bias=True)
# decoder.layer_norm2 ModuleList(
#   (0-11): 12 x LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# )
# decoder.layer_norm2.0 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.1 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.2 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.3 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.4 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.5 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.6 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.7 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.8 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.9 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.10 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm2.11 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15 ModuleList(
#   (0-11): 12 x LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# )
# decoder.layer_norm15.0 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.1 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.2 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.3 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.4 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.5 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.6 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.7 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.8 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.9 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.10 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.layer_norm15.11 LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# decoder.encoder_attn ModuleList(
#   (0-11): 12 x MultiHeadAttention(
#     (q_lin): Linear(in_features=512, out_features=512, bias=True)
#     (k_lin): Linear(in_features=256, out_features=512, bias=True)
#     (v_lin): Linear(in_features=256, out_features=512, bias=True)
#     (out_lin): Linear(in_features=512, out_features=512, bias=True)
#   )
# )
# decoder.encoder_attn.0 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.0.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.0.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.0.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.0.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.1 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.1.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.1.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.1.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.1.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.2 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.2.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.2.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.2.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.2.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.3 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.3.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.3.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.3.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.3.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.4 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.4.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.4.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.4.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.4.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.5 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.5.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.5.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.5.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.5.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.6 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.6.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.6.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.6.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.6.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.7 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.7.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.7.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.7.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.7.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.8 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.8.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.8.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.8.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.8.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.9 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.9.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.9.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.9.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.9.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.10 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.10.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.10.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.10.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.10.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.11 MultiHeadAttention(
#   (q_lin): Linear(in_features=512, out_features=512, bias=True)
#   (k_lin): Linear(in_features=256, out_features=512, bias=True)
#   (v_lin): Linear(in_features=256, out_features=512, bias=True)
#   (out_lin): Linear(in_features=512, out_features=512, bias=True)
# )
# decoder.encoder_attn.11.q_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.encoder_attn.11.k_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.11.v_lin Linear(in_features=256, out_features=512, bias=True)
# decoder.encoder_attn.11.out_lin Linear(in_features=512, out_features=512, bias=True)
# decoder.proj Linear(in_features=512, out_features=10293, bias=True)

# %%
from circuitsvis.tokens import colored_tokens
colored_tokens(["My", "tokens"], [0.123, -0.226])
# Out:
# <div id="circuits-vis-aa609534-e166" style="margin: 15px 0;"/>
#     <script crossorigin type="module">
#     import { render, ColoredTokens } from "https://unpkg.com/circuitsvis@1.43.3/dist/cdn/esm.js";
#     render(
#       "circuits-vis-aa609534-e166",
#       ColoredTokens,
#       {"tokens": ["My", "tokens"], "values": [0.123, -0.226]}
#     )
#     </script>

# %%
trajectory_str = [str(x) for x,y in trajectory]
activations_weights = np.random.rand(len(trajectory_str))

# %%
colored_tokens(trajectory_str, activations_weights)

# %%
from circuitsvis.attention import attention_heads

# %%
fit_activations['ATTN_SCORES'].keys()
# Out:
# dict_keys(['encoder.attentions.0.scores', 'encoder.attentions.1.scores', 'encoder.attentions.2.scores', 'encoder.attentions.3.scores', 'decoder.attentions.0.scores', 'decoder.encoder_attn.0.scores', 'decoder.attentions.1.scores', 'decoder.encoder_attn.1.scores', 'decoder.attentions.2.scores', 'decoder.encoder_attn.2.scores', 'decoder.attentions.3.scores', 'decoder.encoder_attn.3.scores', 'decoder.attentions.4.scores', 'decoder.encoder_attn.4.scores', 'decoder.attentions.5.scores', 'decoder.encoder_attn.5.scores', 'decoder.attentions.6.scores', 'decoder.encoder_attn.6.scores', 'decoder.attentions.7.scores', 'decoder.encoder_attn.7.scores', 'decoder.attentions.8.scores', 'decoder.encoder_attn.8.scores', 'decoder.attentions.9.scores', 'decoder.encoder_attn.9.scores', 'decoder.attentions.10.scores', 'decoder.encoder_attn.10.scores', 'decoder.attentions.11.scores', 'decoder.encoder_attn.11.scores'])

# %%
attention_heads(fit_activations['ATTN_SCORES']['encoder.attentions.0.scores'][(1, 16, 100, 100)].view(16,100,100),trajectory_str)
# Out:
# <div id="circuits-vis-46a009f5-721d" style="margin: 15px 0;"/>
#     <script crossorigin type="module">
#     import { render, AttentionHeads } from "https://unpkg.com/circuitsvis@1.43.3/dist/cdn/esm.js";
#     render(
#       "circuits-vis-46a009f5-721d",
#       AttentionHeads,
#       {"attention": [[[4.0140252113342285, 3.8625853061676025, 3.7516908645629883, 3.856759548187256, 3.69572114944458, 3.692322254180908, 3.705825090408325, 3.2107715606689453, 4.097815036773682, 3.6234755516052246, 3.600106954574585, 3.982253313064575, 3.775721549987793, 3.944432258605957, 3.4522593021392822, 3.971160888671875, 3.428245782852173, 3.2589383125305176, 3.696913242340088, 3.2048065662384033, 3.6186466217041016, 3.1464598178863525, 3.712815284729004, 3.702910900115967, 3.4741628170013428, 3.5662944316864014, 3.636139154434204, 4.115496635437012, 3.2909183502197266, 3.40852427482605, 3.1121370792388916, 3.3195672035217285, 3.426727533340454, 3.456505537033081, 3.357630729675293, 4.12956428527832, 3.568821430206299, 3.906344175338745, 3.7235803604125977, 3.700179100036621, 3.3907382488250732, 4.125586986541748, 4.153646469116211, 3.195378541946411, 3.186694860458374, 3.627777338027954, 3.2349095344543457, 4.0254998207092285, 3.498286485671997, 3.119048833847046, 3.2553353309631348, 3.787719249725342, 4.08712911605835, 3.111133337020874, 3.848675489425659, 3.6678214073181152, 3.686271905899048, 3.810051679611206, 3.6743907928466797, 3.7144289016723633, 3.804698944091797, 3.508026123046875, 3.1260452270507812, 3.466524124145508, 3.2964580059051514, 3.6727287769317627, 3.6754205226898193, 4.042994499206543, 3.5096964836120605, 3.0234882831573486, 3.686307191848755, 3.257711887359619, 4.039710998535156, 3.6620359420776367, 3.843724250793457, 3.244088649749756, 3.6563034057617188, 3.627241849899292, 3.437368392944336, 3.105774164199829, 3.2097935676574707, 3.8403189182281494, 3.9487733840942383, 3.1998517513275146, 3.676772117614746, 3.8937063217163086, 3.9049277305603027, 3.7064497470855713, 3.8813562393188477, 3.7288193702697754, 4.062798976898193, 3.924975872039795, 3.800506830215454, 3.592923164367676, 4.005096435546875, 3.9954850673675537, 3.734494924545288, 3.756354808807373, 4.106021881103516, 3.4147911071777344], [4.04984188079834, 3.928234338760376, 3.8031625747680664, 3.8839659690856934, 3.75742506980896, 3.6731114387512207, 3.7646543979644775, 3.3201088905334473, 4.131237030029297, 3.7426717281341553, 3.6362526416778564, 4.014114856719971, 3.897885799407959, 3.9798872470855713, 3.6218903064727783, 4.001474857330322, 3.52889084815979, 3.3849196434020996, 3.716507911682129, 3.313366174697876, 3.6861355304718018, 3.204775810241699, 3.751448392868042, 3.726418972015381, 3.5673727989196777, 3.602510690689087, 3.7364537715911865, 4.175268650054932, 3.3610081672668457, 3.536309003829956, 3.2457590103149414, 3.4470715522766113, 3.5409698486328125, 3.5919113159179688, 3.5213332176208496, 4.173879146575928, 3.677415609359741, 3.915712833404541, 3.7435030937194824, 3.6702897548675537, 3.4509098529815674, 4.166394233703613, 4.225274562835693, 3.278818368911743, 3.3323991298675537, 3.657510280609131, 3.3166656494140625, 4.1110382080078125, 3.5517306327819824, 3.2156920433044434, 3.418484926223755, 3.8154919147491455, 4.110310077667236, 3.198702812194824, 3.884409189224243, 3.667046070098877, 3.674736499786377, 3.8550479412078857, 3.6650452613830566, 3.7167108058929443, 3.925474166870117, 3.6836342811584473, 3.2259490489959717, 3.5781798362731934, 3.2992544174194336, 3.8406906127929688, 3.77521014213562, 4.111669540405273, 3.6285784244537354, 3.150972604751587, 3.6653175354003906, 3.3300981521606445, 4.159205436706543, 3.7517852783203125, 3.891892671585083, 3.3964107036590576, 3.780961036682129, 3.696190357208252, 3.556130886077881, 3.1961355209350586, 3.3318333625793457, 3.9949772357940674, 3.996206283569336, 3.314236640930176, 3.807750940322876, 3.8591489791870117, 3.9385054111480713, 3.7187016010284424, 3.9917492866516113, 3.7687289714813232, 4.15938138961792, 4.0682220458984375, 3.8532726764678955, 3.664494514465332, 4.031452178955078, 4.018177509307861, 3.8952715396881104, 3.8248419761657715, 4.212010383605957, 3.4721479415893555], [3.256784677505493, 3.093261480331421, 3.679741859436035, 3.222553253173828, 3.64575481 ...

# %%
attention_heads(fit_activations['ATTN_SCORES']['encoder.attentions.0.scores'][(1, 16, 1000, 1000)].view(16,1000,1000),trajectory_str)
# Out:
# <div id="circuits-vis-626d27b7-94a0" style="margin: 15px 0;"/>
#     <script crossorigin type="module">
#     import { render, AttentionHeads } from "https://unpkg.com/circuitsvis@1.43.3/dist/cdn/esm.js";
#     render(
#       "circuits-vis-626d27b7-94a0",
#       AttentionHeads,
#       {"attention": [[[4.227084636688232, 1.2844206094741821, 2.345494031906128, 4.1064982414245605, 3.462681531906128, 2.607901096343994, 2.80352520942688, 2.8681857585906982, 1.72023606300354, 2.6560466289520264, 2.4497289657592773, 2.655857563018799, 2.3858678340911865, 2.537277936935425, 3.036407947540283, 2.6038079261779785, 2.48093318939209, 1.6588269472122192, 2.2482407093048096, 2.7805240154266357, 1.6215732097625732, 2.0213687419891357, 3.7331206798553467, 2.4335033893585205, 1.3610254526138306, 3.723661422729492, 2.1131680011749268, 4.119602680206299, 3.1549432277679443, 3.8508448600769043, 4.144078254699707, 2.6405458450317383, 2.5334317684173584, 2.2158374786376953, 2.106239080429077, 3.4735469818115234, 2.733638286590576, 3.0109667778015137, 1.0427769422531128, 1.4236096143722534, 3.9297561645507812, 2.5339434146881104, 2.421938419342041, 1.0953192710876465, 3.604393720626831, 2.220578908920288, 3.433229684829712, 2.321033239364624, 2.825946092605591, 3.143763542175293, 2.675973653793335, 2.663041114807129, 1.4153740406036377, 1.0331143140792847, 1.226797342300415, 2.8912768363952637, 3.2456493377685547, 2.6897318363189697, 3.285294771194458, 3.78977632522583, 2.069293260574341, 3.1924924850463867, 3.564215898513794, 3.6874170303344727, 2.6915087699890137, 2.299713611602783, 2.8354623317718506, 3.9069979190826416, 3.5198452472686768, 3.7429959774017334, 0.9493188261985779, 2.777034044265747, 3.361032485961914, 3.680501937866211, 3.3172390460968018, 3.4366016387939453, 2.2941861152648926, 2.3462769985198975, 2.4495270252227783, 2.232109785079956, 2.9611387252807617, 4.238134384155273, 2.4988622665405273, 1.9364079236984253, 4.074383735656738, 2.776766777038574, 1.9233227968215942, 2.1435956954956055, 2.1410231590270996, 1.3270186185836792, 1.4724239110946655, 1.1978791952133179, 2.5593409538269043, 0.8008630275726318, 1.3534678220748901, 3.638666868209839, 2.6202287673950195, 0.5857332944869995, 3.105128765106201, 2.4661169052124023], [1.5983320474624634, 3.922231912612915, 2.565783739089966, 1.8262633085250854, 0.4955544173717499, 2.616626024246216, 1.401803731918335, 3.164318323135376, 2.8895459175109863, 2.7419509887695312, 2.5298044681549072, 3.129335403442383, 1.6687004566192627, 3.0845227241516113, 2.990908145904541, 2.57999587059021, 2.6507716178894043, 1.9344481229782104, 1.1658474206924438, 1.7942336797714233, 3.6478164196014404, 2.2770543098449707, 1.381852388381958, 2.624850273132324, 3.7449779510498047, 1.088854432106018, 2.205374240875244, 1.3236552476882935, 2.6544506549835205, 1.8690522909164429, 1.7691899538040161, 2.4812488555908203, 2.392164468765259, 2.4188120365142822, 3.0331308841705322, 1.4294161796569824, 2.9175126552581787, 1.4611698389053345, 3.6427154541015625, 3.8426806926727295, 1.8878309726715088, 2.6498937606811523, 2.5984599590301514, 3.783480405807495, 1.8342888355255127, 2.9982082843780518, 1.7312419414520264, 3.026376962661743, 1.5367674827575684, 2.883507251739502, 2.678051471710205, 2.3055508136749268, 3.5849990844726562, 3.7150731086730957, 3.8797717094421387, 3.058926582336426, 1.4940353631973267, 2.506295919418335, 1.7534184455871582, 1.8741487264633179, 2.355468273162842, 2.3093204498291016, 1.4738658666610718, 1.8659536838531494, 3.0570003986358643, 2.4885714054107666, 2.2833776473999023, 1.7862720489501953, 0.18208317458629608, 1.2783178091049194, 3.6619560718536377, 2.4864017963409424, 1.478768229484558, 1.3894935846328735, 1.4899845123291016, 1.460548996925354, 2.4583990573883057, 2.0423436164855957, 2.412135124206543, 2.4665868282318115, 3.0336856842041016, 1.7504509687423706, 2.5146827697753906, 2.200834035873413, 1.8647775650024414, 2.5958778858184814, 2.162738561630249, 2.36940598487854, 2.4127228260040283, 3.094710350036621, 3.7614057064056396, 3.7713966369628906, 2.6075990200042725, 1.9377092123031616, 3.8860509395599365, 1.4746111631393433, 2.0932257175445557, 3.3368091583251953, 1.4752871990203857, 3.07924222946167], [2.7564754486083984, 2.461392879486084, 4.31147 ...

# %%
fit_activations['ATTN_SCORES']['encoder.attentions.0.scores'][(1, 16, 50, 50)][0].size()
# Out:
# torch.Size([1, 16, 50, 50])

# %%
np.infty=np.inf
times = np.linspace(0, 10, 50)
x = np.cos(times+.1)
y = np.sin(times+.1)
trajectory = np.stack([x, y], axis=1)

model.fit(times, trajectory)
model.print()
# Out:
# x_0' = -1.0629 * x_1
# x_1' = 0.9789 * x_0

# %%
pred_traj = model.predict(times, trajectory[0])
dimension = len(trajectory[0])
for dim in range(dimension):
    plt.scatter(times, trajectory[:, dim], color = f'C{dim}', label=f'$x_{dim}$', marker='o', alpha=.3)
    plt.plot(times, pred_traj[:, dim],  color = f'C{dim}', label=f'$x_{dim}$ predicted')
plt.legend()
