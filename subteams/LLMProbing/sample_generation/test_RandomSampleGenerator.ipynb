# %% [markdown]
# # Testing RandomSampleGenerator

# %%
operators_to_use = "id:1,add:1,mul:1,sin:0.5"
min_dimension = 1
max_dimension = 1
num_samples = 10

# %%
repo_path = '/content/drive/MyDrive/aisc/MIVLDE/subteams/LLMProbing'
odeformer_path = '/content/drive/MyDrive/odeformer'
samples_path = '/content/drive/MyDrive/aisc/samples'

# %%
# clone odeformer into google drive (if needed)
# !git clone https://github.com/sdascoli/odeformer.git {repo_path_folder}

# %%
# give colab permission to access drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append(repo_path)
sys.path.append(odeformer_path)

# %%
import importlib
from sample_generation import SamplesGenerator as sg
importlib.reload(sg)
# Out:
# <module 'sample_generation.SamplesGenerator' from '/content/drive/MyDrive/aisc/MIVLDE/subteams/LLMProbing/sample_generation/SamplesGenerator.py'>

# %%
rsg = sg.RandomSamplesGenerator(samples_path=sample_path, num_samples=10, operators_to_use=operators_to_use, min_dimension=min_dimension, max_dimension=1)

# %%
rsg.generate_random_samples()
# Out:
# [INFO] Data generation complete. Saved 10 samples to /content/drive/MyDrive/aisc/samples
